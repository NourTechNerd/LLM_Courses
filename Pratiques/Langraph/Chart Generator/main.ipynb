# %% [markdown]
# ## Description :
#
# - This project aims to create a simple Graph specialized in generating Charts, based on a User question , for exemple :
#   - Give a Chart for the water level in Alwahda Dam in Morroco ?
#  - Because We will ask questions about Morroco, To get good info from the web the search should be in Arabic or French not english !

# %% [markdown]
# ## Setup :
#
# curl -fsSL https://ollama.com/install.sh | sh
#
# ollama pull llama3-groq-tool-use:8b
#
# ollama pull mistral-nemo:12b
#
# ollama pull llama3.1:8b
#
# ollama pull codegeex4:latest  `Not working with Function calling , but is good at Code related tasks`
#
# ollama pull nomic-embed-text  `For Embedding`
#
#
#
# \n

# %% [markdown]
# ## Build LLMs and Tools :

# %% [markdown]
# ### Tools :

# %%
import os

os.environ["Exa_API_KEY"] = "585502c2-5e53-41ba-bc2d-de8de81b00d6"

# %%
from exa_py import Exa
from langchain.agents import tool

exa = Exa(api_key=os.environ["Exa_API_KEY"])


@tool
def search(query: str, include_domains=None, start_published_date=None):
    """Search for a webpage based on the query.
    Set the optional include_domains (list[str]) parameter to restrict the search to a list of domains.
    Set the optional start_published_date (str) parameter to restrict the search to documents published after the date (YYYY-MM-DD).
    """
    return exa.search_and_contents(
        f"{query}",
        use_autoprompt=True,
        num_results=5,
        include_domains=include_domains,
        start_published_date=start_published_date,
    )
 

@tool
def get_contents(ids: list[str]):
    """Get the contents of a webpage.
    The ids passed in should be a list of ids returned from `search`.
    """
    return exa.get_contents(ids)

# %%
search.args
# Out:
# {'query': {'title': 'Query', 'type': 'string'},
#  'include_domains': {'title': 'Include Domains'},
#  'start_published_date': {'title': 'Start Published Date'}}

# %%
input = {"query":"Barrage Alwahda 2015 2024 maroc"}
response = search.invoke(input)
response.results
# Out:
# [Result(url='https://albaraka.ma/', id='https://albaraka.ma/', title='Guide des Banques et Assurances au Maroc - Albaraka.ma', score=0.1557559221982956, published_date='2015-07-14', author='', text="Emplacements ajoutÃ©es rÃ©cemment  \n \n \n  \nSAHAM Assurance – Assurances Arrahma\nAgence d’assurance Casablanca\n \n Adresse Boulevard Taza, rue 89, nÂ° 112 Rue 300 Hay Moulay Abdellah, Casablanca 20000\n \n   \n \n  \nAgecap – Casablanca – +212 5222-24180\nCourtier d’assurances\n \nAdresse 88, Avenue Mers Sultan, 2?Et., Grand Casablanca, 20000, Casablan, Casablanca 20100\n CatÃ©gories Courtier d'assurances Courtier d'assurances Casablanca\n \n   \n \n  \nCIH Bank – TÃ©mara –\nCIH Bank – Ø§Ù\x84Ù\x82Ø±Ø¶ Ø§Ù\x84Ø¹Ù\x82Ø§Ø±Ù\x8a Ù\x88 Ø§Ù\x84Ø³Ù\x8aØ§Ø\xadÙ\x8a TÃ©mara\n \n Adresse Ave Moulay Ali Chrif, Temara\n \n   \n \n  \nMAMDA MCMA MAEM Socrate\nAgence d’assurance Casablanca\n \n Adresse 1-3Ø\x8c Les rÃ©sidences MASUREL, Rue Socrate, Casablanca 20380\n \n   \n \n  \nAssurance Tifaouine\nAgence d’assurance Agadir\n \n Adresse Num 22,
ence d’assurance Agadir\nAdresse Num 22, Imm Samih, Rue Essaouira, Agadir 80000\nassurance benchlikha WAFA – Marrakech – +212 5244-49335\nAgence d’assurance Marrakech\nAdresse Av. Hassan II, Marrakech 40000\nCatÃ©gories Agence d'assurance Marrakech\nInscrivez votre Agence dans notre base de donnÃ©es\nVous pouvez alimenter et personnaliser votre page avec du texte et des images pour qu’elle soit bien visible dans votre rÃ©gion.\nAjouter votre agence\nAlbaraka.ma\nBanques et Assurances du Maroc\nListe des institutions ...
#  Result(url='https://vigilance.marocmeteo.ma/', id='https://vigilance.marocmeteo.ma/', title='Front Page', score=0.15294426679611206, published_date='2023-07-16', author='', text='المديـــــرية العامة للأرصاد الجويـــــة\nترافقك من أجل  تنمية مستدامة\nالخطوات اللازمة لإنجاز خرائط اليقظة :\n خرائط  اليقظة \nخريطة اليقظة العامة\n   الحد الأقصى لمستوى اليقظة لكل ظاهرة رصدية : \n :   :  \nانظر الخريطة التفاعلية   \nخريطة اليقظة البحرية\n   الحد الأقصى لمستوى اليقظة لكل ظاهرة رصدية : \n :   :  \nانظر الخريطة التفاعلية   \n الظواهر الجوية  القصوى  \nمستويات اليقظة  \nمخاطر مرتبطة بالظواهر الجوية العادية قد تكون أحيانا خطيرة محليا\nمخاطر كبيرة مرتبطة بالظواهر الخطيرة مما يلزم اتخاذ الحيطة و الحذر و تعزيز اليقظة\nمخاطر قصوى مرتبطة بالظواهر الجوية القصوى الخطيرة جدًا؛ مما يلزم إعلام المواطنين بشكل عاجل.\nأسس اليقظة  \n \nالملاحظة الجوية\n \nالنمذجة العددية\n \nالتوقعات الرصدية\n \n ||||I|||| نظام اليقظة الرصدية\n\ufeff\ufeff\n* الأرصاد الجوية\n* اتصل بنا\n* فرنسية\n* العربية\n* الرئيسية\n* خريطة اليقظة العامة\n* خريطة اليقظة البحرية\n* دليل اليقظة\n+ ما هي اليقظة الرصدية ؟\n+ الظواهر الجوية القصوى\n+ نصائح و إرشادات\n* من نحن ؟\n* اتصل بنا\nمهامنا الاخرى.\nالمديـــــرية العامة للأرصاد الجويـــــة ترافقك من أجل تنمية مستدامة مهامنا الأساسية هي المشاركة في المحافظة على الأشخاص والممتلكات من خلال مراقبة الطقس\nالخطوات اللازمة لإنجاز خرائط اليقظة : 1- الرصد و القياس 2- النمذجة العددية والحساب 3- الخبرة في التوقعات 4- الانتاج و البث\nخرائط اليقظة\nخريطة اليقظة العامة\nالحد الأقصى لمستوى اليقظة لكل ظاهرة رصدية :\n2024-01-18 :\n2024-01-19 :\nانظر الخريطة التفاعلية\nخريطة اليقظة البحرية\nالحد الأقصى لمستوى اليقظة لكل ظاهرة رصدية :\n2024-01-18 :\n2024-01-19 :\nانظر الخريطة التفاعلية\nالظواهر الجوية القصوى\nعواصف رعدية\nمزيد من المعلومات\nتساقطات مطرية قوية\nمزيد من المعلومات\nتساقطات ثلجية قوية\nمزيد من المعلومات\nرياح قوية\nمزيد من المعلومات\nموجة الحر\nمزيد من المعلومات\nموجة البرد\nمزيد من المعلومات\nأمواج عاتية\nمزيد من المعلومات\nمستويات اليقظة\nلا يوجد خطر\nمخاطر اعتيادية ومحلية\nمخاطر مرتبطة بالظواهر الجوية العادية قد تكون أحيانا خطيرة محليا\nمخاطر كبيرة\nمخاطر كبيرة مرتبطة بالظواهر الخطيرة مما يلزم اتخاذ الحيطة و الحذر و تعزيز اليقظة\nمخاطر قصوى\nمخاطر قصوى مرتبطة بالظواهر الجوية القصوى الخطيرة جدًا؛ مما يلزم إعلام المواطنين بشكل عاجل.\nأسس اليقظة\nالملاحظة الجوية\nالنمذجة العددية\nالتوقعات الرصدية\n*\n*\nتحديد اليقظة\nاللغات:\n* فرنسية\n* العربية\n2024 - 2018© حقوق الطبع والنشر\nقسم انظمة المعلومات\nالمسؤول عن الموقع: رحمي علي.\nاتصل بنا\n* عنوان:المديرية العامة للأرصاد الجوية ، شارع محمد الطيب الناصري الحي الحسني ، B P 8106 لوازس الدار البيضاء\n* هاتف: (212)5 22.65.49.00 / 65.48.00\n* البريد الإلكتروني: contact@marocmeteo.ma', highlights=None, highlight_scores=None, summary=None),
#  Result(url='https://albarwahnpl.com/', id='https://albarwahnpl.com/', title='Index of /', score=0.15227599442005157, published_date='2023-02-01', author='', text='Name   Last Modified   Size   \n   cgi-bin  2023-02-01 10:02 - \n  \nProudly Served by LiteSpeed Web Server at albarwahnpl.com Port 443 \n||||I|||| Index of /\nName Last Modified Size\ncgi-bin 2023-02-01 10:02 -\nProudly Served by LiteSpeed Web Server at albarwahnpl.com Port 443', highlights=None, highlight_scores=None, summary=None),
#  Result(url='https://www.equipement.gov.ma/AR/Actualites/Pages/Actualites.aspx', id='http://www.equipement.gov.ma/AR/Actualites/Pages/Actualites.aspx', title='', score=0.1504533290863037, published_date='2023-09-09', author='', text='السيد نزار بركة، وزير التحهيز و الماء، يستقبل سفير الجمهورية الفرنسية لدى المملكة المغربية  \n \n \u200bاستقبل السيد نزار بركة، وزير التجهيز والماء، يوم الخميس 16 نونبر 2023، بمقر الوزارة بالرباط، السيد ريمي ريو، المدير العام للوكالة الفرنسية للتنمية، والسيد كريستوف لوكورتييه، سفير جمهورية فرنسا بالمغرب، والسيد كريم بن الشيخ، النائب عن الفرنسيين المقيمين في الخارج، والخبير في مجال البيئة ورئيس مجموعة الصداقة الفرنسية المغربية، والسيدة بنسنت كيتوريه، مديرة الوكالة الفرنسية للتنمية المغرب.\n   أنشطة الموانئ بالمغرب إلى غاية شهر شتنبر من سنة 2023  \n \n \u200bبلغ الرواج الإجمالي على صعيد الموانئ المغربية إلى غاية\nشهر شتنبر من سنة 2023، 155,2 مليون طن مقابل 151 مليون طن في نفس الفترة\nمن السنة الماضية أي بارتفاع بلغ 2,8+%: وقد سجل الرواج الوطني (دون احتساب\nالمسافنة) حجما إجماليا يناهز 81,7 مليون طن أي بانخفاض 3-%، في حين أن نشاط المسافنة سجل رواجا حجمه 73,5 مليون\nطن بزياد
ة الكيلومترية رقم 284على\nمستوى دواري تامسولت و أيت يوبا التابعين\nلجماعة تزي نتاست بإقليم\nتارودانت، و ذلك لإنجاز أشغال إصلاح الأضرار البليغة\nالتي لحقت بقارعة الطريق جراء الهزة الأرضية القوية التي عرفتها بلادنا ليلة\nالجمعة 08 شتنبر 2023على الساعة الحادية عشرة\nوإحدى عشرة دقيقة.\n   حول تداول أخبار زائفة عن حالة بعض سدود المملكة على إثر زلزال "إقليم الحوز"  \n \n على إثر تداول بعض الأخبار، عبر شبكات التواصل\nالاجتماعي، حول تضرر بعض السدود بإقليم الحوز من الزلزال الذي شهدته بلادنا يوم 08\nشتنبر 2023، لا سيما سد لالا تاكركوست وسد ...
#  Result(url='https://www.marocmeteo.ma/', id='https://www.marocmeteo.ma/', title='Météo 07-02-2023', score=0.14847278594970703, published_date='2022-12-31', author='', text="Météo Maroc \n Vigilance générale \n Vigilance marine \n Légende  \n Risque extrême Des phénomènes météorologiques dangereux d'intensité exceptionnelles sont prévus\n Risque important Des phénomènes météorologiques dangereux sont prévus\n Risque usuels Des phénomènes météorologiques habituels mais occasionnellement et localement dangereux\n Pas de risque particulier \nHoule dangereuse\nVents violents\nNB: The vigilance card is updated at least twice a day at \n10H00 et 16H00\n Légende  \n Risque extrême Des phénomènes météorologiques dangereux d'intensité exceptionnelles sont prévus\n Risque important Des phénomènes météorologiques dangereux sont prévus\n Risque occasionnellement menaçant Des phénomènes météorologiques habituels mais occasionnellement et localement dangereux\n Pas de risque particulier \nFortes pluies\nAverses orageuses\nVague de chaleur\nVague de froid\nChutes des neiges\nVents violents\nNB: The vigilance card is updated at least twice a day at \n10H00 et 16H00\nNos secteurs\n Actualités\n \n ||||I|||| MINISTERE DE L’EQUIPEMENT ET DE L’EAU\nDIRECTION GENERALE DE LA METEOROLOGIE\nMaroc meteo - votre partenaire pour un developpement durable\n* Plan du site\n* Nos produits\n* Glossaire\n* Contact\nfr\nar\nMINISTERE DE L’EQUIPEMENT ET DE L’EAU\nDIRECTION GENERALE DE LA METEOROLOGIE\n* Accueil\n* Organisation\n+ Mot du Directeur General\n+ Notre organigramme\n+ Mieux nous connaître\n+ Missions\n+ Système de Management de la Qualité\n+ Plan Stratégique\n* Activités\n+ Observation\n+ Prévision\n+ Climatologie\n+ Recherche & Développement\n+ Instrumentation et Mesures\n+ Coopération Internationale\n* Climat\n+ Climat du Maroc\n+ Normales Climatologiques\n* Produits et Services\n+ Agriculture\n+ Aéronautique\n+ BTP\n+ Eau et Energie\n+ Industrie\n+ Marine\n+ Tourisme & Médias\n+ Transport\n* Actualités\n* Médiathèque\n+ Film institutionnel\n+ Capsules Métiers\n+ Visites Écoles\n+ Événements scientifiques\n+ Reportages Médias\nPrésentation par Mr Nizar Baraka du rapport Maroc Etat du Climat en 2022 le Mercredi 10 mai 2023 à 15h. Visitez la rubrique Climat\n* Météo Maroc\n* Vigilance générale\n* Vigilance marine\nLégende\nNiveaux de vigilance: :\n* Risque extrême\nDes phénomènes météorologiques dangereux d'intensité exceptionnelles sont prévus\n* Risque important\nDes phénomènes météorologiques dangereux sont prévus\n* Risque usuels\nDes phénomènes météorologiques habituels mais occasionnellement et localement dangereux\n* Pas de risque particulier\nLégende des phénomènes:\n* Houle dangereuse\n* Vents violents\nNB: The vigilance card is updated at least twice a day at\n10H00 et 16H00\nLégende\nNiveaux de vigilance: :\n* Risque extrême\nDes phénomènes météorologiques dangereux d'intensité exceptionnelles sont prévus\n* Risque important\nDes phénomènes météorologiques dangereux sont prévus\n* Risque occasionnellement menaçant\nDes phénomènes météorologiques habituels mais occasionnellement et localement dangereux\n* Pas de risque particulier\nLégende des phénomènes:\n* Fortes pluies\n* Averses orageuses\n* Vague de chaleur\n* Vague de froid\n* Chutes des neiges\n* Vents violents\nNB: The vigilance card is updated at least twice a day at\n10H00 et 16H00\nNuit\nMatin\nAprem\nMÉTÉO DES VILLES\n18-05-2023\n* Matin\n°C / °C\n* Aprem\n°C / °C\n* Nuit\n°C / °C\n°\n°\n°\nAgadir Al Hoceima Aousserd Arfoud Assa Beni Mellal Bir anzaran Bir Gandouz Bouarfa Boujdour Boukraa Boulmane Casablanca Dakhla El Jadida Errachidia Essaouira Fes Figuig Guelmime Gueltat zemmour Ifrane Kasba Tadla Kenitra Khenifra Khouribga Laayoune Lagouira Larache Marrakech Meknes Mellilia Midelt Nador Ouarzazate Ouazzane Oujda Oum Dreyga Rabat Safi Sidi Slimane Saidia Ceuta Settat Sidi-Kacem Sidi-Yahia Sidi Ifni Smara Tanger Tan-Tan Taounate Taourirt Tarfaya Taroudant Tata Taza Tetouan Ting ...

# %%
from langchain.agents import Tool
from langchain_experimental.utilities import PythonREPL

Python_Interp = PythonREPL()

# %%
Python_Interp.run("print(1+1)")
# Out:
# Python REPL can execute arbitrary code. Use with caution.
# '2\n'

# %% [markdown]
# ### LLMs :

# %% [markdown]
# #### Converter :

# %%
# Chooser LLM:

#from typing import Literal
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_openai import ChatOpenAI




class RouteQuery(BaseModel):
    """Convert a user question to an optimized and accurate Web search query"""

    query: str = Field(...,description="This is an optimized and accurate Web search query based on the User question")


# LLM with Structered Output
llm = ChatOpenAI(api_key="ollama",model="llama3.1:8b",base_url="http://localhost:11434/v1")
structured_llm_converter = llm.with_structured_output(RouteQuery)

# Prompt
system = """You are an expert at converting french user question to an optimized and accurate french Web search query.\n
Correct any tipo or spelling mistakes in the Web search query before give it, it should be correct.\n
Don't add any additional details or explainations give just the correct and good Web search query."""

converter_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "The User qeustion here :\n {question} "),
    ]
)
  
Converter = converter_prompt | structured_llm_converter

# %% [markdown]
# - Test

# %%
User = "je veux des statistics a propos le remplisage de Brrage Alwahda de 2015 a 2024 ?"
input = {"question":User}
print(input)
converted_question = Converter.invoke(input)
converted_question
# Out:
# {'question': 'je veux des statistics a propos le remplisage de Brrage Alwahda de 2015 a 2024 ?'}
# RouteQuery(query='statistiques remplissage Stade Alwahda 2015 2024')

# %% [markdown]
# #### Reporter :

# %%
#from typing import Literal
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_openai import ChatOpenAI

## We applicate Data Validation to the LLM response to insure that the response instructered as we want

class Reporter_Data(BaseModel):
    """Extract and Orginize web search contents into  the main informations in forme series of values"""

    Report: dict = Field(...,description="""This is python dictionary with keys and values you should extract  from a french web search content and based on the User question""")


# LLM with Structered Output
llm = ChatOpenAI(api_key="ollama",model="mistral-nemo:12b",base_url="http://localhost:11434/v1")
structured_llm_reporter = llm.with_structured_output(Reporter_Data)

# Prompt
system = """You are an expert at Extracting and Orginizing french web search content into  the useful informations in forme of a python dictionary.\n
This python dictionary with keys and values you should extract from the web search content.\n
Give attention to values you see that there are necessary to respond to the User Question.\n
If there a missing value  just keep it empty dont't invent new values from your own . Informations should be just from the French Web search Content.\n
The Web search content may countain outher statistics and values but keep attention only  to values related to the User question.\n
Don't add any additional details or explainations give just the correct and good python dictionary."""

reporter_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "The User qeustion here :\n {question} \n\n The French Web search Content here : \n {Web_Search}"),
    ]
)
  
Reporter = reporter_prompt | structured_llm_reporter

# %% [markdown]
# - Test :

# %%
def Get_Content(results:list)->str:
    Content = "\n-------\n".join(result['content'] for result in results)
    return Content

# %%
Tavily_response = Tavily.invoke(converted_question.query)
Tavily_response
# Out:
# [{'url': 'https://www.espn.com/soccer/team/stats/_/id/7134',
#   'content': 'Get the full Al-Wahda stats for the 2023-24 season on ESPN. Includes leaders in goals, assists, yellow and red cards, and longest streaks.'},
#  {'url': 'https://fr.le360.ma/economie/barrage-al-wahda-un-taux-de-remplissage-considerable-pour-le-plus-grand-barrage-du-maroc_NLPOUJGEPFAVDFMN3H3IHVZWTM/',
#   'content': 'Après une baisse sans précédent, le taux de remplissage du barrage Al Wahda, le plus grand du Royaume, renoue avec une tendance à la hausse, notamment après les récentes pluies du mois de ...'},
#  {'url': 'https://fr.statista.com/statistiques/830874/taux-remplissage-stades-bundesliga/',
#   'content': "Cette statistique représente le taux de remplissage des stades de football des équipes de la Bundesliga durant la saison 2023-2024. Dans le classement des clubs de Bundesliga avec le taux d'occupation de stade le plus élevé, Eintracht Dortmund est en tête. En effet, le stade est toujours plus que complet."},
#  {'url': 'https://fr.soccerway.com/teams/united-arab-emirates/al-wahda-fc-abu-dhabi/5494/',
#   'content': 'Émirats Arabes Unis - Al Wahda FC - Résultats, calendriers, effectif, statistiques, photos, vidéos et news. - Soccerway'},
#  {'url': 'https://alwahda-sc.com/en/',
#   'content': 'AlWahda SC is a leading football club in Abu Dhabi, UAE. Find out the latest news, results, fixtures, and more on their official website.'}]

# %%
input = {"question":User,
"Web_Search":Get_Content(Tavily_response)}
print(input)
report = Reporter.invoke(input)
report
# Out:
# {'question': "je veux savoir Niveu d'eau dans le Barrage Alwahda au Maroc anne les 5 derniers annes ?", 'Web_Search': "Lire aussi : Barrages: au 15 avril, un taux de remplissage de 51% du bassin du Sebou. « En tant que plus grand réservoir du Royaume, le barrage Al Wahda joue un rôle essentiel dans la ...\n-------\nDR N° 1097 du 19 au 25 July 2024 Voir le ... rapport révèle des différences significatives entre les barrages en termes de niveaux d'eau et de taux de remplissage : Le barrage d'Al Wahda ...\n-------\nLa Direction régionale du Nord de la branche Eau de l'Office national de l'électricité et de l'eau potable va lancer la mise à niveau du système de comptage et de celui de la régulation du barrage Al Wahda. X. ECONOMIE; ... A la découverte du Maroc; Morocco Now; SIAM 2024; CAN 2023; Voyager au temps du Covid; Assemblée Annuelles ...\n-------\nAu 20 février 2022, le taux de remplissage des principaux barrages du pays s'élevait à peine à 33,1%, soit près de 15% de moins que le pourcentage ... Stress hydrique : l'assèchement des grands barrages du Maroc vu par satellite En 2022, les principales retenues d'eau du Maroc ont atteint des niveaux de remplissage historiquement bas ...\n-------\nAl Massira, inauguré en 1979, est le deuxième plus grand réservoir artificiel d'eau du Maroc après Al Wahda, avec un volume de 2,6 km³. Ces deux des principaux barrages du Royaume se trouvent affectés par le manque d'eau. Ils sont presque à sec, si l'on considère que 10 % du volume d'eau correspond à de la vase dans la structure."}

# %% [markdown]
# ### Grader :

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.pydantic_v1 import BaseModel, Field
from typing import Literal

## We applicate Data Validation to the LLM response to insure 
# that the response instructered as we want

class Grader_Data(BaseModel):
    """Evaluate The Report of the Reporter Agent as Good/Bad report"""

    Grade: Literal["Good","Bad"] = Field(...,description="""This field is your evaluation for a report of informations if there good to 
    responde a User question or not""")

# LLM with Structered Output
llm = ChatOpenAI(api_key="ollama",model="llama3.1:8b",base_url="http://localhost:11434/v1")
structured_llm_grader = llm.with_structured_output(Grader_Data)

# Prompt
system = """You are an expert at evaluating Reports and informations.\n
Given the a set of values in forme of a python dictionary extracted by a Reporter Agent  from a french web
search contents and a  User question you should evaluate if the python dictionary give enought 
data to answer the User question OR Not.\n
If you see that values of the python dictionary are missing or not enought to answer the User question 
Grade it by "Bad", Outherwise grade it by "Good".\n
The python dictionary will be used by anouther Agent to create a Chart.\n
Your response should be Good/Bad key word.\n
Don't add any additional details or explanations just the key word."""

grader_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "The python dictionary here :\n {Python_Dictionary}\n\n The User question here :\n {question}")
    ]
)
        
Grader = grader_prompt | structured_llm_grader

# %%
User = 
Dictionary = 
input = {"Python_Dictionary":Dictionary,"question":User}
Grade = Grader.invoke(input)
Grade

# %% [markdown]
# ## Initialize The Graph:

# %%
from typing_extensions import TypedDict
import pandas as pd
from langgraph.graph import StateGraph, START, END

class State(TypedDict):
    Question: str
    SQL_query: str
    Tables_Names: str
    Tables_Schemas: str
    Tables_Need: str
    Grade: str
    Finale_Response: pd.DataFrame

graph_builder = StateGraph(State)

# %% [markdown]
# ## Nodes Functions :

# %%
from Colors import BLUE,RED,YELLOW,GREEN,RESET

# %% [markdown]
# ### Tools :

# %% [markdown]
# ### LLMs:

# %% [markdown]
# ## Design the Graph:

# %% [markdown]
# ### Build :

# %% [markdown]
# ### Visualize :

# %% [markdown]
# ## Interact with The Graph :

# %%
# Run
inputs = {
    "Question": "Which customers are supported by the employee with the first name 'Jane'?" +"be accurate and Optimale"
}
for output in SQL_Graph.stream(inputs):
    for key, value in output.items():
        # Node
        print(f"Node :{key}")
        print(f"State :{value}")
    print("\n")

value["Finale_Response"]
